# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("/content/school.csv")

# %%
df
# Out:
#     private   apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# ...

# %%
df.head()
# Out:
#   private  apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    s_f_ratio  perc_alumni  expend  grad_rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56
# ...

# %%
df.head(10)
# Out:
#   private  apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
# 5     Yes   587     479     158         38         62          678
# 6     Yes   353     340     103         17         45          416
# 7     Yes  1899    1720     489         37         68         1594
# 8     Yes  1038     839     227         30         63          973
# 9     Yes   582     498     172         21         44          799
#
#    p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# ...

# %%
df.tail()
# Out:
#     private   apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# 772         2029      6797        3900    500      1200   60        60
# 773         1107     11520        4960    600      1250   73        75
# 774          166      6900        4200    617       781   67        75
# 775           83     19840        6510    630      2115   96        96
# 776         1726      4990        3560    500      1250   75        75
#
#      s_f_ratio  perc_alumni  expend  grad_rate
# 772       21.0           14    4469         40
# ...

# %%
df.tail(15)
# Out:
#     private   apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 762     Yes    469     435     227         17         39          851
# 763     Yes   4186    1245     526         81         96         1988
# 764     Yes    167     130      46         16         50          199
# 765     Yes   1239    1017     383         10         34         1207
# 766      No   3325    2047    1301         20         45         5800
# 767      No   2320    1805     769         24         61         3395
# 768     Yes    152     128      75         17         41          282
# 769     Yes   1979    1739     575         42         68         1980
# 770     Yes   1501     935     273         51         83         1059
# 771     Yes   2768    2314     682         49         86         2802
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# ...

# %%
df.columns
# Out:
# Index(['private', 'apps', 'accept', 'enroll', 'top10perc', 'top25perc',
#        'f_undergrad', 'p_undergrad', 'outstate', 'room_board', 'books',
#        'personal', 'phd', 'terminal', 's_f_ratio', 'perc_alumni', 'expend',
#        'grad_rate'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['private',
#  'apps',
#  'accept',
#  'enroll',
#  'top10perc',
#  'top25perc',
#  'f_undergrad',
#  'p_undergrad',
#  'outstate',
#  'room_board',
#  'books',
#  'personal',
#  'phd',
#  'terminal',
#  's_f_ratio',
#  'perc_alumni',
#  'expend',
#  'grad_rate']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   private      777 non-null    object
#  1   apps         777 non-null    int64
#  2   accept       777 non-null    int64
#  3   enroll       777 non-null    int64
#  4   top10perc    777 non-null    int64
#  5   top25perc    777 non-null    int64
#  6   f_undergrad  777 non-null    int64
#  7   p_undergrad  777 non-null    int64
#  8   outstate     777 non-null    int64
#  9   room_board   777 non-null    int64
#  10  books        777 non-null    int64
#  11  personal     777 non-null    int64
#  12  phd          777 non-null    int64
#  13  terminal     777 non-null    int64
#  14  s_f_ratio    777 non-null    float64
#  15  perc_alumni  777 non-null    int64
#  16  expend       777 non-null    int64
#  17  grad_rate    777 non-null    int64
# dtypes: float64(1), int64(16), object(1)
# ...

# %%
df.nunique()
# Out:
# private          2
# apps           711
# accept         693
# enroll         581
# top10perc       82
# top25perc       89
# f_undergrad    714
# p_undergrad    566
# outstate       640
# room_board     553
# books          122
# personal       294
# phd             78
# terminal        65
# s_f_ratio      173
# perc_alumni     61
# expend         744
# grad_rate       81
# dtype: int64

# %%
df.head()
# Out:
#   private  apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    s_f_ratio  perc_alumni  expend  grad_rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56
# ...

# %%
df['grad_rate'] = df['perc_alumni'].apply(lambda x:  x*(20/100))

# %%
df.head()
# Out:
#   private  apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    s_f_ratio  perc_alumni  expend  grad_rate
# 0       18.1           12    7041        2.4
# 1       12.2           16   10527        3.2
# ...

# %%
df['terminal'] = df['expend'] - df['accept']

# %%
df.head()
# Out:
#   private  apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# 0          537      7440        3300    450      2200   70      5809
# 1         1227     12280        6450    750      1500   29      8603
# 2           99     11250        3750    400      1165   53      7638
# 3           63     12960        5450    450       875   92     18667
# 4          869      7560        4120    800      1500   76     10776
#
#    s_f_ratio  perc_alumni  expend  grad_rate
# 0       18.1           12    7041        2.4
# 1       12.2           16   10527        3.2
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (12,6))
plt.plot(df['private'], df['apps'])
plt.show()
